# %%
pip install pandas numpy openpyxl rapidfuzz matplotlib seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.5 MB/s  0:00:003.1 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
